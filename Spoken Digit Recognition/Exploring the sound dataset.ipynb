# %% [markdown]
# ## Spoken Digit Recognition

# %% [markdown]
# References:
#
# http://cs230.stanford.edu/projects_fall_2020/reports/55617928.pdf
#
# https://www.kaggle.com/code/davids1992/speech-representation-and-data-exploration/notebook

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import librosa
import librosa.display

import IPython.display as ipd

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ***Unzip the recordings.zip folder***

# %%
# !unzip /content/drive/MyDrive/spoken_digit/recordings.zip
# Out:
# Archive:  /content/drive/MyDrive/spoken_digit/recordings.zip
#    creating: recordings/
#   inflating: recordings/0_jackson_0.wav
#   inflating: recordings/0_jackson_1.wav
#   inflating: recordings/0_jackson_10.wav
#   inflating: recordings/0_jackson_11.wav
#   inflating: recordings/0_jackson_12.wav
#   inflating: recordings/0_jackson_13.wav
#   inflating: recordings/0_jackson_14.wav
#   inflating: recordings/0_jackson_15.wav
#   inflating: recordings/0_jackson_16.wav
#   inflating: recordings/0_jackson_17.wav
#   inflating: recordings/0_jackson_18.wav
#   inflating: recordings/0_jackson_19.wav
#   inflating: recordings/0_jackson_2.wav
#   inflating: recordings/0_jackson_20.wav
#   inflating: recordings/0_jackson_21.wav
#   inflating: recordings/0_jackson_22.wav
#   inflating: recordings/0_jackson_23.wav
#   inflating: recordings/0_jackson_24.wav
#   inflating: recordings/0_jackson_25.wav
#   inflating: recordings/0_jackson_26.wav
#   inflating: recordings/0_jackson_27.wav
# ...

# %%
# Read the all file names in the recordings folder given by us
# (If you get entire path, it is very useful in future)
# Save those files names as list in "all_files"

# %%
# https://thispointer.com/python-how-to-get-the-list-of-all-files-in-a-zip-archive/

from zipfile import ZipFile

with ZipFile('/content/drive/MyDrive/spoken_digit/recordings.zip', 'r') as zipObj:
   # Get list of files names in zip
   listOfFiles = zipObj.namelist()
   # Iterate over the list of file names in given list & print them
   for elem in listOfFiles:
       elem

all_files = os.listdir('/content/recordings')
len(all_files)
# Out:
# 2000

# %% [markdown]
# <font size=4>Grader function 1 </font>

# %%
def grader_files():
    temp = len(all_files) == 2000
    temp1 = all([x[-3:] == "wav" for x in all_files])
    temp = temp and temp1
    return temp
grader_files()
# Out:
# True

# %% [markdown]
# ## Exploring the sound dataset

# %%
# It is a good programming practise to explore the dataset that you are dealing with. 
# This dataset is unique in itself because it has sound as input.
# https://colab.research.google.com/github/Tyler-Hilbert/AudioProcessingInPythonWorkshop/blob/master/AudioProcessingInPython.ipynb
# Visualize the data and write code to play 2-3 sound samples in the notebook for better understanding.
# Please go through the following reference video https://www.youtube.com/watch?v=37zCgCdV468

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('jackson 0')
fileName = 'recordings/0_jackson_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('nicolas 0')
fileName = 'recordings/0_nicolas_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('theo 0')
fileName = 'recordings/0_theo_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('yweweler 0')
fileName = 'recordings/0_yweweler_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Graph is like double bell for zero.

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('jackson 1')
fileName = 'recordings/1_jackson_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('nicolas 1')
fileName = 'recordings/1_nicolas_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('theo 1')
fileName = 'recordings/1_theo_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('yweweler 1')
fileName = 'recordings/1_yweweler_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The graph for the digit '1' is mostly similar except the last one. The graph changed a bit in the beginning of the speech because it looks like the person gave a slight pause in the beginning.

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('jackson 5')
fileName = 'recordings/5_jackson_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('nicolas 5')
fileName = 'recordings/5_nicolas_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('theo 5')
fileName = 'recordings/5_theo_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize = (7, 5))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('yweweler 5')
fileName = 'recordings/5_yweweler_0.wav'
data, sample_rate = librosa.load(fileName)
librosa.display.waveplot(data, sr = sample_rate)
ipd.Audio(fileName)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The frequency pattern for same digit have similarity for every individual so if our model can train on this pattern then we can easily predict the audio to get number.

# %% [markdown]
# The peak frequency depends on the tone of the person so we are taking the frequency pattern into the consideration.
